# %% [markdown]
# ### Task 1: Exploratory Data Analysis (EDA):

# %%
import os
os.environ["OMP_NUM_THREADS"]="1"

# %%
import pandas as pd
df = pd.read_csv("wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
num_cols = df.select_dtypes(include=['number']).columns

for col in num_cols:
    print(f"Descriptive statistics for column: {col}")
    print(df[col].describe())
    print("==============================================")
# Out:
# Descriptive statistics for column: Type
# count    1.780000e+02
# mean     1.596725e-16
# std      1.002821e+00
# min     -1.213944e+00
# 25%     -1.213944e+00
# 50%      7.996036e-02
# 75%      1.373864e+00
# max      1.373864e+00
# Name: Type, dtype: float64
# ...
# Descriptive statistics for column: Alcohol
# count    1.780000e+02
# mean    -8.382808e-16
# std      1.002821e+00
# min     -2.434235e+00
# 25%     -7.882448e-01
# 50%      6.099988e-02
# 75%      8.361286e-01
# max      2.259772e+00
# Name: Alcohol, dtype: float64
# ...
# Descriptive statistics for column: Malic
# count    1.780000e+02
# mean    -1.197544e-16
# std      1.002821e+00
# min     -1.432983e+00
# 25%     -6.587486e-01
# 50%     -4.231120e-01
# 75%      6.697929e-01
# max      3.109192e+00
# Name: Malic, dtype: float64
# ...
# Descriptive statistics for column: Ash
# count    1.780000e+02
# mean    -8.370333e-16
# std      1.002821e+00
# min     -3.679162e+00
# 25%     -5.721225e-01
# 50%     -2.382132e-02
# ...

# %%
import matplotlib.pyplot as plt
df["Alcohol"].plot(kind="hist")
plt.title("Histogram of Alcohol")
plt.xlabel("Alcohol")
# Out:
# Text(0.5, 0, 'Alcohol')

# %%
df["Malic"].plot(kind="hist")
plt.title("Histogram of Malic")
plt.xlabel("Malic")
# Out:
# Text(0.5, 0, 'Malic')

# %%
df["Ash"].plot(kind="hist")
plt.title("Histogram of Ash")
plt.xlabel("Ash")
# Out:
# Text(0.5, 0, 'Ash')

# %%
df["Alcalinity"].plot(kind="hist")
plt.title("Histogram of Alcalinity")
plt.xlabel("Alcalinity")
# Out:
# Text(0.5, 0, 'Alcalinity')

# %%
df["Magnesium"].plot(kind="hist")
plt.title("Histogram of Magnesium")
plt.xlabel("Magnesium")
# Out:
# Text(0.5, 0, 'Magnesium')

# %%
df["Phenols"].plot(kind="hist")
plt.title("Histogram of Phenols")
plt.xlabel("Phenols")
# Out:
# Text(0.5, 0, 'Phenols')

# %%
df["Flavanoids"].plot(kind="hist")
plt.title("Histogram of Flavanoids")
plt.xlabel("Flavanoids")
# Out:
# Text(0.5, 0, 'Flavanoids')

# %%
df["Nonflavanoids"].plot(kind="hist")
plt.title("Histogram of Nonflavanoids")
plt.xlabel("Nonflavanoids")
# Out:
# Text(0.5, 0, 'Nonflavanoids')

# %%
df["Proanthocyanins"].plot(kind="hist")
plt.title("Histogram of Proanthocyanins")
plt.xlabel("Proanthocyanins")
# Out:
# Text(0.5, 0, 'Proanthocyanins')

# %%
df["Color"].plot(kind="hist")
plt.title("Histogram of Color")
plt.xlabel("Color")
# Out:
# Text(0.5, 0, 'Color')

# %%
df["Hue"].plot(kind="hist")
plt.title("Histogram of Hue")
plt.xlabel("Hue")
# Out:
# Text(0.5, 0, 'Hue')

# %%
df["Dilution"].plot(kind="hist")
plt.title("Histogram of Dilution")
plt.xlabel("Dilution")
# Out:
# Text(0.5, 0, 'Dilution')

# %%
df["Proline"].plot(kind="hist")
plt.title("Histogram of Proline")
plt.xlabel("Proline")
# Out:
# Text(0.5, 0, 'Proline')

# %%
df["Alcohol"].plot(kind="box",vert=False)
plt.title("Boxplot of Alcohol")
plt.xlabel("Alcohol")
# Out:
# Text(0.5, 0, 'Alcohol')

# %%
df["Malic"].plot(kind="box",vert=False)
plt.title("Boxplot of Malic")
plt.xlabel("Malic")
# Out:
# Text(0.5, 0, 'Malic')

# %%
df["Ash"].plot(kind="box",vert=False)
plt.title("Boxplot of Ash")
plt.xlabel("Ash")
# Out:
# Text(0.5, 0, 'Ash')

# %%
df["Alcalinity"].plot(kind="box",vert=False)
plt.title("Boxplot of Alcalinity")
plt.xlabel("Alcalinity")
# Out:
# Text(0.5, 0, 'Alcalinity')

# %%
df["Magnesium"].plot(kind="box",vert=False)
plt.title("Boxplot of Magnesium")
plt.xlabel("Magnesium")
# Out:
# Text(0.5, 0, 'Magnesium')

# %%
df["Phenols"].plot(kind="box",vert=False)
plt.title("Boxplot of Phenols")
plt.xlabel("Phenols")
# Out:
# Text(0.5, 0, 'Phenols')

# %%
df["Flavanoids"].plot(kind="box",vert=False)
plt.title("Boxplot of Flavanoids")
plt.xlabel("Flavanoids")
# Out:
# Text(0.5, 0, 'Flavanoids')

# %%
df["Nonflavanoids"].plot(kind="box",vert=False)
plt.title("Boxplot of Nonflavanoids")
plt.xlabel("Nonflavanoids")
# Out:
# Text(0.5, 0, 'Nonflavanoids')

# %%
df["Proanthocyanins"].plot(kind="box",vert=False)
plt.title("Boxplot of Proanthocyanins")
plt.xlabel("Proanthocyanins")
# Out:
# Text(0.5, 0, 'Proanthocyanins')

# %%
df["Color"].plot(kind="box",vert=False)
plt.title("Boxplot of Color")
plt.xlabel("Color")
# Out:
# Text(0.5, 0, 'Color')

# %%
df["Hue"].plot(kind="box",vert=False)
plt.title("Boxplot of Hue")
plt.xlabel("Hue")
# Out:
# Text(0.5, 0, 'Hue')

# %%
df["Dilution"].plot(kind="box",vert=False)
plt.title("Boxplot of Dilution")
plt.xlabel("Dilution")
# Out:
# Text(0.5, 0, 'Dilution')

# %%
df["Proline"].plot(kind="box",vert=False)
plt.title("Boxplot of Proline")
plt.xlabel("Proline")
# Out:
# Text(0.5, 0, 'Proline')

# %% [markdown]
# ### Task 2: Dimensionality Reduction with PCA:

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()

# %%
df_new = pd.DataFrame(SS.fit_transform(df))
df_new.columns = list(df)
df = df_new
df
# Out:
#          Type   Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0   -1.213944  1.518613 -0.562250  0.232053   -1.169593   1.913905  0.808997
# 1   -1.213944  0.246290 -0.499413 -0.827996   -2.490847   0.018145  0.568648
# 2   -1.213944  0.196879  0.021231  1.109334   -0.268738   0.088358  0.808997
# 3   -1.213944  1.691550 -0.346811  0.487926   -0.809251   0.930918  2.491446
# 4   -1.213944  0.295700  0.227694  1.840403    0.451946   1.281985  0.808997
# ..        ...       ...       ...       ...         ...        ...       ...
# 173  1.373864  0.876275  2.974543  0.305159    0.301803  -0.332922 -0.985614
# 174  1.373864  0.493343  1.412609  0.414820    1.052516   0.158572 -0.793334
# 175  1.373864  0.332758  1.744744 -0.389355    0.151661   1.422412 -1.129824
# 176  1.373864  0.209232  0.227694  0.012732    0.151661   1.422412 -1.033684
# 177  1.373864  1.395086  1.583165  1.365208    1.502943  -0.262708 -0.392751
#
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA()

# %%
pc = pca.fit_transform(df)
pc = pd.DataFrame(pc)
pc.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -3.522934  1.453098 -0.164795 -0.013273  0.737345  0.300716  0.573876
# 1 -2.528858 -0.330019 -2.026707 -0.417144 -0.283214  0.884309 -0.029716
# 2 -2.785029  1.036936  0.983238  0.664232 -0.387565 -0.468842  0.488305
# 3 -3.922588  2.768210 -0.174968  0.565088 -0.324360 -0.262616 -0.398364
# 4 -1.407511  0.867773  2.025829 -0.440906  0.227949  0.593762  0.447876
#
#          7         8         9         10        11        12        13
# 0 -0.055637 -0.458765 -1.065570 -0.420494  0.552928 -0.302978  0.200857
# 1 -1.010372  0.218806  0.020182 -0.130020  0.394971 -0.146645  0.126402
# 2  0.268957  1.222769  0.106249 -0.279074  0.001898  0.021278 -0.055752
# 3 -0.618844 -0.114658 -0.107671  0.773866 -0.230929 -0.501277  0.019903
# 4 -0.434937 -0.261548 -0.112434 -0.537931 -0.226686  0.274109 -0.517498

# %%
 #2.Determine the optimal number of principal components using techniques like scree plot or cumulative explained variance.
import numpy as np
explained_variance = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(pca.explained_variance_ratio_)+1),pca.explained_variance_ratio_, marker='o',linestyle='--')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Task 3: Clustering with Original Data:

# %%
X = df.iloc[:,1:]

# %%
from sklearn.cluster import KMeans
K_cluster = KMeans(n_clusters=3)

# %%
df["K_3"] = K_cluster.fit_predict(X)

# %%
plt.scatter(df['Alcohol'], df['Proline'], c=df["K_3"], cmap='rainbow')
plt.xlabel('Alcohol')
plt.ylabel('Proline')
plt.show()

# %%
import numpy as np
from sklearn.metrics import silhouette_score
score=silhouette_score(X,df["K_3"])
print("K_3 score:", np.round(score,3))
# Out:
# K_3 score: 0.281

# %%
scores = []

# %%
for i in range(2,11,1):
    from sklearn.cluster import KMeans
    K_cluster = KMeans(n_clusters=i)
    df["K_3"] = K_cluster.fit_predict(X)
    from sklearn.metrics import silhouette_score
    scores.append(silhouette_score(X,df["K_3"]))

# %%
np.round(scores,3)
# Out:
# array([0.26 , 0.285, 0.227, 0.227, 0.199, 0.152, 0.146, 0.126, 0.15 ])

# %%
import matplotlib.pyplot as plt
plt.scatter(range(2,11),scores)    
plt.plot(range(2,11),scores,color='red')
plt.show()

# %% [markdown]
# ### Task 4: Clustering with PCA Data:

# %%
pc
# Out:
#            0         1         2         3         4         5         6   \
# 0   -3.522934  1.453098 -0.164795 -0.013273  0.737345  0.300716  0.573876
# 1   -2.528858 -0.330019 -2.026707 -0.417144 -0.283214  0.884309 -0.029716
# 2   -2.785029  1.036936  0.983238  0.664232 -0.387565 -0.468842  0.488305
# 3   -3.922588  2.768210 -0.174968  0.565088 -0.324360 -0.262616 -0.398364
# 4   -1.407511  0.867773  2.025829 -0.440906  0.227949  0.593762  0.447876
# ..        ...       ...       ...       ...       ...       ...       ...
# 173  3.627996  2.206617 -0.343668  0.751705 -1.004109  1.143155  0.843455
# 174  2.942729  1.752263  0.207480  0.399381  0.154223  0.062465  0.139947
# 175  3.027272  2.756040 -0.940803  0.607758  1.128136 -0.005290  0.733026
# 176  2.755222  2.293784 -0.550474 -0.391570  1.067083 -1.012562  0.755423
# 177  3.496336  2.760608  1.013151  0.349630 -1.005136 -0.377223  0.015307
#
#            7         8         9         10        11        12        13
# ...

# %%
X_pc = pc.iloc[:,1:]

# %%
from sklearn.cluster import KMeans
K_cluster = KMeans(n_clusters=3)

# %%
df["K_pc_3"] = K_cluster.fit_predict(X_pc)

# %%
import numpy as np
from sklearn.metrics import silhouette_score
score=silhouette_score(X_pc,df["K_pc_3"])
print("K_pc_3 score:", np.round(score,3))
# Out:
# K_pc_3 score: 0.12

# %%
plt.scatter(pc.iloc[:,1:2], pc.iloc[:,2:3], c=df["K_pc_3"], cmap='rainbow')
plt.show()

# %%
scores1 = []

# %%
for i in range(2,11,1):
    from sklearn.cluster import KMeans
    K_cluster = KMeans(n_clusters=i)
    df["K_pc_3"] = K_cluster.fit_predict(X_pc)
    from sklearn.metrics import silhouette_score
    scores1.append(silhouette_score(X_pc,df["K_pc_3"]))

# %%
np.round(scores1,3)
# Out:
# array([0.231, 0.162, 0.113, 0.101, 0.106, 0.118, 0.113, 0.119, 0.103])

# %%
import matplotlib.pyplot as plt
plt.scatter(range(2,11,1),scores1)    
plt.plot(range(2,11,1),scores1,color='red')
plt.show()

# %% [markdown]
# ### Task 5: Comparison and Analysis:

# %%
import matplotlib.pyplot as plt
plt.scatter(range(2,11),scores)    
plt.plot(range(2,11),scores,color='red')
plt.scatter(range(2,11,1),scores1)    
plt.plot(range(2,11,1),scores1,color='red')
plt.show()

# %% [markdown]
# 2. Similarities and Differences in Clustering Results
#
# *Similarities:
# In both the original and PCA-transformed datasets, the general trend of clustering quality (y-axis) decreasing as the number of
# clusters increases is consistent.
# *Differences:
# The scores for the PCA-transformed data (orange in the third plot) are generally lower than thosefor the original data (blue),
# especially for higher k values.
#
# 3.Impact of Dimensionality Reduction on Clustering Performance
#
# *PCA reduces noise and removes redundant correlations between features,which can help clustering algorithms like K-Means find more stable groups.
# *Scores have been significantly reduced after dimensionality reduction on clustering performance.

# %% [markdown]
# 4. Trade-offs Between Using PCA vs Clustering on Original Dataset
#
# Clustering on Original Dataset:
# 1.Uses full variance, including noise
# 2.More sensitive to noisy or irrelevant features
# 3.Performance & Speed are Slower on high-dimensional data
# 4.Cluster Quality may be higher if all features are informative
#
# Clustering after PCA:
# 1 Keeps only top-variance components (possible info loss)
# 2.Reduces noise and redundancy
# 3.Performance & Speed are Faster due to reduced dimensions
# 4.Cluster Quality often slightly lower but more stable

# %% [markdown]
# ### Task 6: Conclusion and Insights

# %% [markdown]
# 1.Key Findings and Insights:
#   1.Standardization ensured all features contributed equally to the PCA and clustering processes.
#   2.PCA successfully reduced the dataset’s dimensionality while retaining most of the variance (~95%), making the data more compact and less noisy.
#
# 2.Practical Implications of Using PCA and Clustering:
#   1.PCA helps simplify high-dimensional datasets, improves computational efficiency, and reduces the risk of overfitting by removing
#   redundant or noisy features.
#   2.Clustering uncovers underlying group structures in data, which can be valuable for segmentation, anomaly detection, and pattern discovery.
#   3.Combining PCA and clustering is especially beneficial for large, high-dimensional datasets where noise and feature correlation could
#   hinder cluster stability.
#
# 3.Recommendations:
#   1.Use PCA before clustering when working with high-dimensional data, particularly when many features are correlated or contain noise.
#   2.Perform clustering directly on the original dataset if the number of features is manageable and all features are expected to be informative.
#   3.Always compare clustering results before and after PCA to ensure that the dimensionality reduction has not removed critical separation information.
#   4.For practical projects, balance interpretability (original features) against efficiency and stability (PCA features).
