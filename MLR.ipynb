# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("ToyotaCorolla - MLR.csv")
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# 3             4      5    1165
# 4             4      5    1170
# ...         ...    ...     ...
# 1431          4      5    1025
# 1432          4      5    1015
# 1433          4      5    1015
# 1434          4      5    1015
# 1435          4      5    1114
#
# [1436 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# min     1300.00000     2.000000        4.0     3.000000  1000.00000
# 25%     1400.00000     3.000000        4.0     5.000000  1040.00000
# 50%     1600.00000     4.000000        4.0     5.000000  1070.00000
# 75%     1600.00000     5.000000        4.0     5.000000  1085.00000
# max    16000.00000     5.000000        4.0     6.000000  1615.00000

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.isnull().sum()
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
 df.select_dtypes(include='number')
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500         23  46986   90          0  2000      3          4      5
# 1     13750         23  72937   90          0  2000      3          4      5
# 2     13950         24  41711   90          0  2000      3          4      5
# 3     14950         26  48000   90          0  2000      3          4      5
# 4     13750         30  38500   90          0  2000      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1431   7500         69  20544   86          0  1300      3          4      5
# 1432  10845         72  19000   86          0  1300      3          4      5
# 1433   8500         71  17016   86          0  1300      3          4      5
# 1434   7250         70  16916   86          0  1300      3          4      5
# 1435   6950         76      1  110          0  1600      5          4      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...      ...
# 1431    1025
# 1432    1015
# 1433    1015
# 1434    1015
# 1435    1114
#
# [1436 rows x 10 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
num_cols = df.select_dtypes(include=[np.number]).columns
for col in num_cols[:10]:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f"Histogram of {col}")
    plt.show()

# %%
for feature in ["Age_08_04", "KM", "HP", "cc","Doors","Cylinders","Gears","Weight"]:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=df[feature], y=df["Price"])
    plt.title(f"Scatterplot: Price vs {feature}")
    plt.xlabel(feature)
    plt.ylabel("Price")
    plt.show()

# %%
plt.boxplot(df["Age_08_04"],vert=False)
plt.title("Boxplot of Age_08_04")
plt.show()

# %%
plt.boxplot(df["KM"],vert=False)
plt.title("Boxplot of KM")
plt.show()

# %%
plt.boxplot(df["HP"],vert=False)
plt.title("Boxplot of HP")
plt.show()

# %%
plt.boxplot(df["Weight"],vert=False)
plt.title("Boxplot of Weight")
plt.show()

# %%
#Data transformation
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df["Fuel_Type"] = LE.fit_transform(df["Fuel_Type"])
df
# Out:
#       Price  Age_08_04     KM  Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986          1   90          0  2000      3
# 1     13750         23  72937          1   90          0  2000      3
# 2     13950         24  41711          1   90          0  2000      3
# 3     14950         26  48000          1   90          0  2000      3
# 4     13750         30  38500          1   90          0  2000      3
# ...     ...        ...    ...        ...  ...        ...   ...    ...
# 1431   7500         69  20544          2   86          0  1300      3
# 1432  10845         72  19000          2   86          0  1300      3
# 1433   8500         71  17016          2   86          0  1300      3
# 1434   7250         70  16916          2   86          0  1300      3
# 1435   6950         76      1          2  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# 3             4      5    1165
# 4             4      5    1170
# ...         ...    ...     ...
# 1431          4      5    1025
# 1432          4      5    1015
# 1433          4      5    1015
# 1434          4      5    1015
# 1435          4      5    1114
#
# [1436 rows x 11 columns]

# %% [markdown]
# ### Multiple Linear Regression Models

# %% [markdown]
# ### Model 1

# %%
X = df.iloc[:,1:11]
Y = df["Price"]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()

# %%
model1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
pd.DataFrame(model1.coef_)
# Out:
#               0
# 0 -1.260981e+02
# 1 -1.762117e-02
# 2  4.655590e+02
# 3  2.370528e+01
# 4  2.920130e+02
# 5 -2.637095e-02
# 6 -2.876212e+01
# 7  1.136868e-13
# 8  6.475571e+02
# 9  1.990233e+01

# %%
Y_pred_train = model1.predict(X_train)
Y_pred_test = model1.predict(X_test)

# %%
train_acc = []
test_acc = []

# %%
#Accuracy
for i in range(1,101):
    from sklearn.model_selection import train_test_split
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)
    from sklearn.linear_model import LinearRegression
    model1 = LinearRegression()
    model1.fit(X_train,Y_train)
    Y_pred_train = model1.predict(X_train)
    Y_pred_test = model1.predict(X_test)
    train_acc.append(r2_score(Y_train,Y_pred_train))
    test_acc.append(r2_score(Y_test,Y_pred_test))

# %%
print("Model1 training data performance: ",np.round(np.mean(train_acc),2))
print("Model1 testing data performance: ",np.round(np.mean(test_acc),2))
# Out:
# Model1 training data performance:  0.87
# Model1 testing data performance:  0.83

# %%
training_acc = []
testing_acc = []

# %%
#Loss function
for i in range(1,101):
    from sklearn.model_selection import train_test_split
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)
    from sklearn.linear_model import LinearRegression
    model1 = LinearRegression()
    model1.fit(X_train,Y_train)
    Y_pred_train = model1.predict(X_train)
    Y_pred_test = model1.predict(X_test)
    training_acc.append(mean_squared_error(Y_train,Y_pred_train,squared=False))
    testing_acc.append(mean_squared_error(Y_test,Y_pred_test,squared=False))

# %%
print("Model1 train rmse: ",np.round(np.mean(training_acc),2))
print("Model1 test rmse: ",np.round(np.mean(testing_acc),2))
# Out:
# Model1 train rmse:  1319.6
# Model1 test rmse:  1496.99

# %% [markdown]
# ### Lasso and Ridge methods

# %%
#Lasso regression
from sklearn.linear_model import Lasso
lass_c = Lasso(alpha=4.0)

# %%
lass_c.fit(X_train,Y_train)
# Out:
# Lasso(alpha=4.0)

# %%
d1 = pd.DataFrame(list(X))
d2 = pd.DataFrame(model1.coef_)
d3 = pd.DataFrame(lass_c.coef_)

# %%
df_coef = pd.concat([d1,d2,d3],axis=1)
df_coef
# Out:
#            0             0           0
# 0  Age_08_04 -1.221022e+02 -121.737268
# 1         KM -1.620423e-02   -0.016411
# 2  Fuel_Type  2.892229e+02  211.667287
# 3         HP  2.747479e+01   28.596563
# 4  Automatic  1.706538e+02   86.951817
# 5         cc -1.749579e+00   -1.831192
# 6      Doors -7.769693e+01  -77.207109
# 7  Cylinders -6.252776e-13    0.000000
# 8      Gears  4.195289e+02  285.663107
# 9     Weight  2.455823e+01   24.538488

# %%
X_new = X.drop(X.columns[[2,4,7]],axis=1)
X_new
# Out:
#       Age_08_04     KM   HP    cc  Doors  Gears  Weight
# 0            23  46986   90  2000      3      5    1165
# 1            23  72937   90  2000      3      5    1165
# 2            24  41711   90  2000      3      5    1165
# 3            26  48000   90  2000      3      5    1165
# 4            30  38500   90  2000      3      5    1170
# ...         ...    ...  ...   ...    ...    ...     ...
# 1431         69  20544   86  1300      3      5    1025
# 1432         72  19000   86  1300      3      5    1015
# 1433         71  17016   86  1300      3      5    1015
# 1434         70  16916   86  1300      3      5    1015
# 1435         76      1  110  1600      5      5    1114
#
# [1436 rows x 7 columns]

# %%
train_acc = []
test_acc = []

# %%
#Accuracy
for i in range(1,101):
    from sklearn.model_selection import train_test_split
    X_train,X_test,Y_train,Y_test = train_test_split(X_new,Y,test_size=0.2)
    from sklearn.linear_model import LinearRegression
    model1 = LinearRegression()
    model1.fit(X_train,Y_train)
    Y_pred_train = model1.predict(X_train)
    Y_pred_test = model1.predict(X_test)
    train_acc.append(r2_score(Y_train,Y_pred_train))
    test_acc.append(r2_score(Y_test,Y_pred_test))

# %%
print("Model1 training data performance: ",np.round(np.mean(train_acc),2))
print("Model1 testing data performance: ",np.round(np.mean(test_acc),2))
# Out:
# Model1 training data performance:  0.86
# Model1 testing data performance:  0.83

# %%
training_acc = []
testing_acc = []

# %%
#Loss function
for i in range(1,101):
    from sklearn.model_selection import train_test_split
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)
    from sklearn.linear_model import LinearRegression
    model1 = LinearRegression()
    model1.fit(X_train,Y_train)
    Y_pred_train = model1.predict(X_train)
    Y_pred_test = model1.predict(X_test)
    training_acc.append(mean_squared_error(Y_train,Y_pred_train,squared=False))
    testing_acc.append(mean_squared_error(Y_test,Y_pred_test,squared=False))

# %%
print("Model1 train rmse: ",np.round(np.mean(training_acc),2))
print("Model1 test rmse: ",np.round(np.mean(testing_acc),2))
# Out:
# Model1 train rmse:  1324.77
# Model1 test rmse:  1451.72

# %%
#Ridge regression
from sklearn.linear_model import Ridge
Ridge_c = Ridge(alpha=9.0)
Ridge_c.fit(X_train,Y_train)
# Out:
# Ridge(alpha=9.0)

# %%
d1 = pd.DataFrame(list(X))
d2 = pd.DataFrame(model1.coef_)
d3 = pd.DataFrame(Ridge_c.coef_)

# %%
df_coef = pd.concat([d1,d2,d3],axis=1)
df_coef
# Out:
#            0             0           0
# 0  Age_08_04 -1.262877e+02 -126.129844
# 1         KM -1.660870e-02   -0.016789
# 2  Fuel_Type  4.683822e+02  411.746276
# 3         HP  2.362030e+01   24.454340
# 4  Automatic  3.088288e+02  268.034576
# 5         cc -5.016676e-03   -0.007284
# 6      Doors  2.706925e+01   24.413402
# 7  Cylinders -1.662670e-12    0.000000
# 8      Gears  4.293477e+02  335.236674
# 9     Weight  1.792596e+01   17.777462

# %%
X_new = X.drop(X.columns[[1,7]],axis=1)
X_new
# Out:
#       Age_08_04  Fuel_Type   HP  Automatic    cc  Doors  Gears  Weight
# 0            23          1   90          0  2000      3      5    1165
# 1            23          1   90          0  2000      3      5    1165
# 2            24          1   90          0  2000      3      5    1165
# 3            26          1   90          0  2000      3      5    1165
# 4            30          1   90          0  2000      3      5    1170
# ...         ...        ...  ...        ...   ...    ...    ...     ...
# 1431         69          2   86          0  1300      3      5    1025
# 1432         72          2   86          0  1300      3      5    1015
# 1433         71          2   86          0  1300      3      5    1015
# 1434         70          2   86          0  1300      3      5    1015
# 1435         76          2  110          0  1600      5      5    1114
#
# [1436 rows x 8 columns]

# %%
train_acc = []
test_acc = []

# %%
#Accuracy
for i in range(1,101):
    from sklearn.model_selection import train_test_split
    X_train,X_test,Y_train,Y_test = train_test_split(X_new,Y,test_size=0.2)
    from sklearn.linear_model import LinearRegression
    model1 = LinearRegression()
    model1.fit(X_train,Y_train)
    Y_pred_train = model1.predict(X_train)
    Y_pred_test = model1.predict(X_test)
    train_acc.append(r2_score(Y_train,Y_pred_train))
    test_acc.append(r2_score(Y_test,Y_pred_test))

# %%
print("Model1 training data performance: ",np.round(np.mean(train_acc),2))
print("Model1 testing data performance: ",np.round(np.mean(test_acc),2))
# Out:
# Model1 training data performance:  0.85
# Model1 testing data performance:  0.78

# %%
training_acc = []
testing_acc = []

# %%
#Loss function
for i in range(1,101):
    from sklearn.model_selection import train_test_split
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)
    from sklearn.linear_model import LinearRegression
    model1 = LinearRegression()
    model1.fit(X_train,Y_train)
    Y_pred_train = model1.predict(X_train)
    Y_pred_test = model1.predict(X_test)
    training_acc.append(mean_squared_error(Y_train,Y_pred_train,squared=False))
    testing_acc.append(mean_squared_error(Y_test,Y_pred_test,squared=False))

# %%
print("Model1 train rmse: ",np.round(np.mean(training_acc),2))
print("Model1 test rmse: ",np.round(np.mean(testing_acc),2))
# Out:
# Model1 train rmse:  1328.47
# Model1 test rmse:  1460.83

# %% [markdown]
# ### Model 2:

# %%
df.corr()
# Out:
#               Price  Age_08_04        KM  Fuel_Type        HP  Automatic  \
# Price      1.000000  -0.876590 -0.569960  -0.022157  0.314990   0.033081
# Age_08_04 -0.876590   1.000000  0.505672   0.080261 -0.156622   0.031717
# KM        -0.569960   0.505672  1.000000  -0.420586 -0.333538  -0.081854
# Fuel_Type -0.022157   0.080261 -0.420586   1.000000  0.409476   0.069718
# HP         0.314990  -0.156622 -0.333538   0.409476  1.000000   0.013144
# Automatic  0.033081   0.031717 -0.081854   0.069718  0.013144   1.000000
# cc         0.126389  -0.098084  0.102683  -0.277239  0.035856   0.066740
# Doors      0.185326  -0.148359 -0.036197  -0.026935  0.092424  -0.027654
# Cylinders       NaN        NaN       NaN        NaN       NaN        NaN
# Gears      0.063104  -0.005364  0.015023   0.069655  0.209477  -0.098555
# Weight     0.581198  -0.470253 -0.028598  -0.505303  0.089614   0.057249
#
#                  cc     Doors  Cylinders     Gears    Weight
# Price      0.126389  0.185326        NaN  0.063104  0.581198
# Age_08_04 -0.098084 -0.148359        NaN -0.005364 -0.470253
# KM         0.102683 -0.036197        NaN  0.015023 -0.028598
# Fuel_Type -0.277239 -0.026935        NaN  0.069655 -0.505303
# HP         0.035856  0.092424        NaN  0.209477  0.089614
# Automatic  0.066740 -0.027654        NaN -0.098555  0.057249
# cc         1.000000  0.079903        NaN  0.014629  0.335637
# Doors      0.079903  1.000000        NaN -0.160141  0.302618
# Cylinders       NaN       NaN        NaN       NaN       NaN
# Gears      0.014629 -0.160141        NaN  1.000000  0.020613
# Weight     0.335637  0.302618        NaN  0.020613  1.000000

# %%
X1 = df.iloc[:,1:3]
X2 = df["Weight"]
X = pd.concat([X1,X2],axis=1)
Y = df["Price"]

# %% [markdown]
# ### MLR

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model2 = LinearRegression()

# %%
model2.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model2.coef_
# Out:
# array([-1.22598086e+02, -2.36580232e-02,  1.95748777e+01])

# %%
Y_pred_train = model2.predict(X_train)
Y_pred_test = model2.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np

# %%
train_acc = []
test_acc = []

# %%
#Accuracy
for i in range(1,101):
    from sklearn.model_selection import train_test_split
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)
    from sklearn.linear_model import LinearRegression
    model2 = LinearRegression()
    model2.fit(X_train,Y_train)
    Y_pred_train = model2.predict(X_train)
    Y_pred_test = model2.predict(X_test)
    train_acc.append(r2_score(Y_train,Y_pred_train))
    test_acc.append(r2_score(Y_test,Y_pred_test))

# %%
print("Model1 training data performance: ",np.round(np.mean(train_acc),2))
print("Model1 testing data performance: ",np.round(np.mean(test_acc),2))
# Out:
# Model1 training data performance:  0.85
# Model1 testing data performance:  0.84

# %%
training_acc = []
testing_acc = []

# %%
#loss function
for i in range(1,101):
    from sklearn.model_selection import train_test_split
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)
    from sklearn.linear_model import LinearRegression
    model2 = LinearRegression()
    model2.fit(X_train,Y_train)
    Y_pred_train = model2.predict(X_train)
    Y_pred_test = model2.predict(X_test)
    training_acc.append(mean_squared_error(Y_train,Y_pred_train,squared=False))
    testing_acc.append(mean_squared_error(Y_test,Y_pred_test,squared=False))

# %%
print("Model1 training data loss function: ",np.round(np.mean(training_acc),2))
print("Model1 testing data loss function: ",np.round(np.mean(testing_acc),2))
# Out:
# Model1 training data loss function:  1417.73
# Model1 testing data loss function:  1397.49

# %%
d2 = pd.DataFrame(model2.coef_)
d1 = pd.DataFrame(list(X))

# %%
df_coef = pd.concat([d1,d2],axis=1)
df_coef
# Out:
#            0           0
# 0  Age_08_04 -120.972814
# 1         KM   -0.024370
# 2     Weight   19.284886

# %%
#Lasso
from sklearn.linear_model import Lasso
lass_c = Lasso(alpha=12.0)

# %%
lass_c.fit(X_train,Y_train)
d3 = pd.DataFrame(lass_c.coef_)

# %%
df_coef = pd.concat([d1,d2,d3],axis=1)
df_coef
# Out:
#            0           0           0
# 0  Age_08_04 -120.972814 -120.919009
# 1         KM   -0.024370   -0.024383
# 2     Weight   19.284886   19.289013

# %%
#Ridge regression
from sklearn.linear_model import Ridge
Ridge_c = Ridge(alpha=12.0)

# %%
Ridge_c.fit(X_train,Y_train)
d4 = pd.DataFrame(lass_c.coef_)

# %%
df_coef = pd.concat([d1,d2,d4],axis=1)
df_coef
# Out:
#            0           0           0
# 0  Age_08_04 -120.972814 -120.919009
# 1         KM   -0.024370   -0.024383
# 2     Weight   19.284886   19.289013

# %% [markdown]
# ### Model 3

# %%
#Fitting model3 using Principal Component Analysis
df
# Out:
#       Price  Age_08_04     KM  Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986          1   90          0  2000      3
# 1     13750         23  72937          1   90          0  2000      3
# 2     13950         24  41711          1   90          0  2000      3
# 3     14950         26  48000          1   90          0  2000      3
# 4     13750         30  38500          1   90          0  2000      3
# ...     ...        ...    ...        ...  ...        ...   ...    ...
# 1431   7500         69  20544          2   86          0  1300      3
# 1432  10845         72  19000          2   86          0  1300      3
# 1433   8500         71  17016          2   86          0  1300      3
# 1434   7250         70  16916          2   86          0  1300      3
# 1435   6950         76      1          2  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# 3             4      5    1165
# 4             4      5    1170
# ...         ...    ...     ...
# 1431          4      5    1025
# 1432          4      5    1015
# 1433          4      5    1015
# 1434          4      5    1015
# 1435          4      5    1114
#
# [1436 rows x 11 columns]

# %%
x1 = df.iloc[:,1:5]
x2 = df.iloc[:,6:11]
X = pd.concat([x1,x2],axis=1)
X
# Out:
#       Age_08_04     KM  Fuel_Type   HP    cc  Doors  Cylinders  Gears  Weight
# 0            23  46986          1   90  2000      3          4      5    1165
# 1            23  72937          1   90  2000      3          4      5    1165
# 2            24  41711          1   90  2000      3          4      5    1165
# 3            26  48000          1   90  2000      3          4      5    1165
# 4            30  38500          1   90  2000      3          4      5    1170
# ...         ...    ...        ...  ...   ...    ...        ...    ...     ...
# 1431         69  20544          2   86  1300      3          4      5    1025
# 1432         72  19000          2   86  1300      3          4      5    1015
# 1433         71  17016          2   86  1300      3          4      5    1015
# 1434         70  16916          2   86  1300      3          4      5    1015
# 1435         76      1          2  110  1600      5          4      5    1114
#
# [1436 rows x 9 columns]

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
SS_X = SS.fit_transform(X)
SS_X = pd.DataFrame(SS_X)
SS_X.columns = list(X)
SS_X
# Out:
#       Age_08_04        KM  Fuel_Type        HP        cc     Doors  Cylinders  \
# 0     -1.771966 -0.574695  -2.337868 -0.768042  0.997419 -1.085139        0.0
# 1     -1.771966  0.117454  -2.337868 -0.768042  0.997419 -1.085139        0.0
# 2     -1.718184 -0.715386  -2.337868 -0.768042  0.997419 -1.085139        0.0
# 3     -1.610620 -0.547650  -2.337868 -0.768042  0.997419 -1.085139        0.0
# 4     -1.395491 -0.801028  -2.337868 -0.768042  0.997419 -1.085139        0.0
# ...         ...       ...        ...       ...       ...       ...        ...
# 1431   0.702015 -1.279939   0.354336 -1.035138 -0.652594 -1.085139        0.0
# 1432   0.863362 -1.321120   0.354336 -1.035138 -0.652594 -1.085139        0.0
# 1433   0.809579 -1.374036   0.354336 -1.035138 -0.652594 -1.085139        0.0
# 1434   0.755797 -1.376703   0.354336 -1.035138 -0.652594 -1.085139        0.0
# 1435   1.078490 -1.827849   0.354336  0.567440  0.054555  1.014941        0.0
#
#          Gears    Weight
# 0    -0.140425  1.758561
# 1    -0.140425  1.758561
# 2    -0.140425  1.758561
# 3    -0.140425  1.758561
# 4    -0.140425  1.853577
# ...        ...       ...
# 1431 -0.140425 -0.901883
# 1432 -0.140425 -1.091915
# 1433 -0.140425 -1.091915
# 1434 -0.140425 -1.091915
# 1435 -0.140425  0.789399
#
# [1436 rows x 9 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA()
pc = pca.fit_transform(SS_X)
pc = pd.DataFrame(pc)
pc
# Out:
#              0         1         2         3         4         5         6  \
# 0     2.994762 -0.295019  0.445299 -2.248822  0.480739  0.313587  0.218432
# 1     3.089901  0.107050  0.565640 -2.041540  0.370958  0.472940 -0.217457
# 2     2.959510 -0.349921  0.425685 -2.267761  0.506650  0.287058  0.343085
# 3     2.950737 -0.198832  0.464546 -2.171139  0.487239  0.337401  0.309553
# 4     2.908189 -0.258895  0.448778 -2.155214  0.524842  0.331500  0.644087
# ...        ...       ...       ...       ...       ...       ...       ...
# 1431 -1.480073  0.410955 -0.468086 -1.303059  0.353344 -0.521901  1.043400
# 1432 -1.645349  0.507867 -0.478488 -1.243860  0.404605 -0.571762  1.115963
# 1433 -1.636709  0.450302 -0.492537 -1.282902  0.409401 -0.589808  1.113236
# 1434 -1.621161  0.421927 -0.497849 -1.306895  0.406228 -0.596284  1.078865
# 1435 -0.088167 -1.252546 -0.485899  0.913087  0.042276 -0.119883  1.990639
#
#              7             8
# 0    -0.349274  1.839108e-16
# 1    -0.196085  1.225699e-16
# 2    -0.377071  1.962769e-16
# 3    -0.333264  1.812062e-16
# 4    -0.318204  1.856894e-16
# ...        ...           ...
# 1431 -0.046571  4.641739e-17
# 1432 -0.161204  8.488259e-17
# 1433 -0.176257  8.967481e-17
# 1434 -0.180189  9.001379e-17
# 1435  0.048977 -3.065592e-19
#
# [1436 rows x 9 columns]

# %%
X_pc = pc.iloc[:,0:5]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X_pc,Y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model3 = LinearRegression()

# %%
model3.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model3.coef_
# Out:
# array([ 1030.14893161, -2010.70456007,   -24.88633548, -1018.06696783,
#         -219.06329363])

# %%
Y_pred_train = model3.predict(X_train)
Y_pred_test = model3.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np

# %%
train_acc = []
test_acc = []

# %%
#Accuracy
for i in range(1,101):
    from sklearn.model_selection import train_test_split
    X_train,X_test,Y_train,Y_test = train_test_split(X_pc,Y,test_size=0.2)
    from sklearn.linear_model import LinearRegression
    model3 = LinearRegression()
    model3.fit(X_train,Y_train)
    Y_pred_train = model3.predict(X_train)
    Y_pred_test = model3.predict(X_test)
    train_acc.append(r2_score(Y_train,Y_pred_train))
    test_acc.append(r2_score(Y_test,Y_pred_test))

# %%
print("Model3 training data performance: ",np.round(np.mean(train_acc),2))
print("Model3 testing data performance: ",np.round(np.mean(test_acc),2))
# Out:
# Model3 training data performance:  0.85
# Model3 testing data performance:  0.84

# %%
d2 = pd.DataFrame(model3.coef_)
d1 = pd.DataFrame(list(SS_X))

# %%
#Lasso
from sklearn.linear_model import Lasso
lass_c = Lasso(alpha=15.0)

# %%
lass_c.fit(X_train,Y_train)
d3 = pd.DataFrame(lass_c.coef_)

# %%
df_coef = pd.concat([d1,d2,d3],axis=1)
df_coef
# Out:
#            0            0            0
# 0  Age_08_04   968.934084   972.830755
# 1         KM -1986.249700 -1980.817950
# 2  Fuel_Type   -57.525469   -31.604491
# 3         HP -1044.590743 -1015.419168
# 4         cc  -343.189601  -275.030861
# 5      Doors          NaN          NaN
# 6  Cylinders          NaN          NaN
# 7      Gears          NaN          NaN
# 8     Weight          NaN          NaN

# %%
#Ridge regression
from sklearn.linear_model import Ridge
Ridge_c = Ridge(alpha=12.0)

# %%
Ridge_c.fit(X_train,Y_train)
d3 = pd.DataFrame(Ridge_c.coef_)

# %%
df_coef = pd.concat([d1,d2,d3],axis=1)
df_coef
# Out:
#            0            0            0
# 0  Age_08_04   968.934084   965.854448
# 1         KM -1986.249700 -1976.364460
# 2  Fuel_Type   -57.525469   -54.361544
# 3         HP -1044.590743 -1031.004040
# 4         cc  -343.189601  -330.418075
# 5      Doors          NaN          NaN
# 6  Cylinders          NaN          NaN
# 7      Gears          NaN          NaN
# 8     Weight          NaN          NaN

# %% [markdown]
# ### Interview Questions

# %% [markdown]
# ### 1.What is Normalization & Standardization and how is it helpful?
# Ans: Normalization: Normalization is the process of adjusting values measured on different scales to a common scale, typically between 0 and 1 (or sometimes -1 and 1).Standardization transforms data to have a mean of 0 and a standard deviation of 1, which is more robust to outliers and is ideal for algorithms assuming a normal distribution.
# How is it helpful: Normalization is useful when you need all the data to be within a specific range and don’t assume any particular data distribution. It's typically used with algorithms sensitive to the magnitude of features, such as neural networks and k-nearest neighbors.

# %% [markdown]
# ### 2.What techniques can be used to address multicollinearity in multiple linear regression?
# Ans:To address multicollinearity in multiple linear regression, you can use several techniques. One of the simplest methods is to remove one of the highly correlated predictors after identifying them using a correlation matrix or the Variance Inflation Factor (VIF). Alternatively, you can combine correlated variables into a single new variable, for example, by creating a composite index or using a dimensionality reduction technique like Principal Component Analysis (PCA). Another effective approach is to use regularization techniques such as Ridge or Lasso regression, which penalize the model's coefficients and are designed to handle correlated features. Finally, increasing the sample size can sometimes help by providing more data to better distinguish between the effects of correlated variables.
