# %%
import pandas as pd
import numpy as np
df = pd.read_excel("EastWestAirlines.xlsx",sheet_name="data")
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %% [markdown]
# ### Data Preprocessing:

# %%
df.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
df["Balance"].plot(kind='box')
# Out:
# <Axes: >

# %%
Q1 = np.percentile(df["Balance"],25)
Q3 = np.percentile(df["Balance"],75)
IQR = Q3 - Q1
UW = Q3 + (1.5 * IQR)
LW = Q1 - (1.5 * IQR)

# %%
print("Number of outliers present in Balance Column : ",len(df["Balance"][df["Balance"]>UW]))
print("Number of outliers present in Balance Column : ",len(df["Balance"][df["Balance"]<LW]))
# Out:
# Number of outliers present in Balance Column :  266
# Number of outliers present in Balance Column :  0

# %%
df["Balance"][df["Balance"]>UW] = UW

# %%
print("Number of outliers present in Balance Column : ",len(df["Balance"][df["Balance"]>UW]))
print("Number of outliers present in Balance Column : ",len(df["Balance"][df["Balance"]<LW]))
# Out:
# Number of outliers present in Balance Column :  0
# Number of outliers present in Balance Column :  0

# %%
df["Balance"].plot(kind='box')
# Out:
# <Axes: >

# %%
df["Bonus_miles"].plot(kind='box')
# Out:
# <Axes: >

# %%
Q1 = np.percentile(df["Bonus_miles"],25)
Q3 = np.percentile(df["Bonus_miles"],75)
IQR = Q3 - Q1
UW = Q3 + (1.5 * IQR)
LW = Q1 - (1.5 * IQR)

# %%
print("Number of outliers present in Bonus_miles Column : ",len(df["Bonus_miles"][df["Bonus_miles"]>UW]))
print("Number of outliers present in Bonus_miles Column : ",len(df["Bonus_miles"][df["Bonus_miles"]<LW]))
# Out:
# Number of outliers present in Bonus_miles Column :  280
# Number of outliers present in Bonus_miles Column :  0

# %%
df["Bonus_miles"][df["Bonus_miles"]>UW] = UW

# %%
print("Number of outliers present in Bonus_miles Column : ",len(df["Bonus_miles"][df["Bonus_miles"]>UW]))
print("Number of outliers present in Bonus_miles Column : ",len(df["Bonus_miles"][df["Bonus_miles"]<LW]))
# Out:
# Number of outliers present in Bonus_miles Column :  0
# Number of outliers present in Bonus_miles Column :  0

# %%
df["Bonus_miles"].plot(kind='box')
# Out:
# <Axes: >

# %%
df["Days_since_enroll"].plot(kind='box')
# Out:
# <Axes: >

# %%
df["Qual_miles"].plot(kind='box')
# Out:
# <Axes: >

# %%
#Treating outliers
Q1 = np.percentile(df["Qual_miles"],25)
Q3 = np.percentile(df["Qual_miles"],75)
IQR = Q3 - Q1
UW = Q3 + (1.5 * IQR)
LW = Q1 - (1.5 * IQR)

# %%
print("Number of outliers present in Qual_miles Column : ",len(df["Qual_miles"][df["Qual_miles"]>UW]))
print("Number of outliers present in Qual_miles Column : ",len(df["Qual_miles"][df["Qual_miles"]<LW]))
# Out:
# Number of outliers present in Qual_miles Column :  226
# Number of outliers present in Qual_miles Column :  0

# %%
df["Qual_miles"][df["Qual_miles"]>UW] = UW

# %%
print("Number of outliers present in Qual_miles Column : ",len(df["Qual_miles"][df["Qual_miles"]>UW]))
print("Number of outliers present in Qual_miles Column : ",len(df["Qual_miles"][df["Qual_miles"]<LW]))
# Out:
# Number of outliers present in Qual_miles Column :  0
# Number of outliers present in Qual_miles Column :  0

# %%
df["Qual_miles"].plot(kind='box')
# Out:
# <Axes: >

# %%
df["cc1_miles"].plot(kind='box')
# Out:
# <Axes: >

# %%
df["cc2_miles"].plot(kind='box')
# Out:
# <Axes: >

# %%
#Treating outliers
Q1 = np.percentile(df["cc2_miles"],25)
Q3 = np.percentile(df["cc2_miles"],75)
IQR = Q3 - Q1
UW = Q3 + (1.5 * IQR)
LW = Q1 - (1.5 * IQR)

# %%
print("Number of outliers present in cc2_miles Column : ",len(df["cc2_miles"][df["cc2_miles"]>UW]))
print("Number of outliers present in cc2_miles Column : ",len(df["cc2_miles"][df["cc2_miles"]<LW]))
# Out:
# Number of outliers present in cc2_miles Column :  43
# Number of outliers present in cc2_miles Column :  0

# %%
df["cc2_miles"][df["cc2_miles"]>UW] = UW

# %%
print("Number of outliers present in cc2_miles Column : ",len(df["cc2_miles"][df["cc2_miles"]>UW]))
print("Number of outliers present in cc2_miles Column : ",len(df["cc2_miles"][df["cc2_miles"]<LW]))
# Out:
# Number of outliers present in cc2_miles Column :  0
# Number of outliers present in cc2_miles Column :  0

# %%
df["cc2_miles"].plot(kind='box')
# Out:
# <Axes: >

# %%
df["cc3_miles"].plot(kind='box')
# Out:
# <Axes: >

# %%
#Treating outliers
Q1 = np.percentile(df["cc3_miles"],25)
Q3 = np.percentile(df["cc3_miles"],75)
IQR = Q3 - Q1
UW = Q3 + (1.5 * IQR)
LW = Q1 - (1.5 * IQR)

# %%
print("Number of outliers present in cc3_miles Column : ",len(df["cc3_miles"][df["cc3_miles"]>UW]))
print("Number of outliers present in cc3_miles Column : ",len(df["cc3_miles"][df["cc3_miles"]<LW]))
# Out:
# Number of outliers present in cc3_miles Column :  18
# Number of outliers present in cc3_miles Column :  0

# %%
df["cc3_miles"][df["cc3_miles"]>UW] = UW

# %%
print("Number of outliers present in cc3_miles Column : ",len(df["cc3_miles"][df["cc3_miles"]>UW]))
print("Number of outliers present in cc3_miles Column : ",len(df["cc3_miles"][df["cc3_miles"]<LW]))
# Out:
# Number of outliers present in cc3_miles Column :  0
# Number of outliers present in cc3_miles Column :  0

# %%
df["Bonus_trans"].plot(kind='box')
# Out:
# <Axes: >

# %%
#Treating outliers
Q1 = np.percentile(df["Bonus_trans"],25)
Q3 = np.percentile(df["Bonus_trans"],75)
IQR = Q3 - Q1
UW = Q3 + (1.5 * IQR)
LW = Q1 - (1.5 * IQR)

# %%
print("Number of outliers present in Bonus_trans Column : ",len(df["Bonus_trans"][df["Bonus_trans"]>UW]))
print("Number of outliers present in Bonus_trans Column : ",len(df["Bonus_trans"][df["Bonus_trans"]<LW]))
# Out:
# Number of outliers present in Bonus_trans Column :  63
# Number of outliers present in Bonus_trans Column :  0

# %%
df["Bonus_trans"][df["Bonus_trans"]>UW] = UW

# %%
print("Number of outliers present in Bonus_trans Column : ",len(df["Bonus_trans"][df["Bonus_trans"]>UW]))
print("Number of outliers present in Bonus_trans Column : ",len(df["Bonus_trans"][df["Bonus_trans"]<LW]))
# Out:
# Number of outliers present in Bonus_trans Column :  0
# Number of outliers present in Bonus_trans Column :  0

# %%
df["Bonus_trans"].plot(kind='box')
# Out:
# <Axes: >

# %%
df["Flight_miles_12mo"].plot(kind='box')
# Out:
# <Axes: >

# %%
#Treating outliers
Q1 = np.percentile(df["Flight_miles_12mo"],25)
Q3 = np.percentile(df["Flight_miles_12mo"],75)
IQR = Q3 - Q1
UW = Q3 + (1.5 * IQR)
LW = Q1 - (1.5 * IQR)

# %%
print("Number of outliers present in Flight_miles_12mo Column : ",len(df["Flight_miles_12mo"][df["Flight_miles_12mo"]>UW]))
print("Number of outliers present in Flight_miles_12mo Column : ",len(df["Flight_miles_12mo"][df["Flight_miles_12mo"]<LW]))
# Out:
# Number of outliers present in Flight_miles_12mo Column :  569
# Number of outliers present in Flight_miles_12mo Column :  0

# %%
df["Flight_miles_12mo"][df["Flight_miles_12mo"]>UW] = UW

# %%
print("Number of outliers present in Flight_miles_12mo Column : ",len(df["Flight_miles_12mo"][df["Flight_miles_12mo"]>UW]))
print("Number of outliers present in Flight_miles_12mo Column : ",len(df["Flight_miles_12mo"][df["Flight_miles_12mo"]<LW]))
# Out:
# Number of outliers present in Flight_miles_12mo Column :  0
# Number of outliers present in Flight_miles_12mo Column :  0

# %%
df["Flight_miles_12mo"].plot(kind='box')
# Out:
# <Axes: >

# %%
df["Flight_trans_12"].plot(kind='box')
# Out:
# <Axes: >

# %%
#Treating outliers
Q1 = np.percentile(df["Flight_trans_12"],25)
Q3 = np.percentile(df["Flight_trans_12"],75)
IQR = Q3 - Q1
UW = Q3 + (1.5 * IQR)
LW = Q1 - (1.5 * IQR)

# %%
print("Number of outliers present in Flight_trans_12 Column : ",len(df["Flight_trans_12"][df["Flight_trans_12"]>UW]))
print("Number of outliers present in Flight_trans_12 Column : ",len(df["Flight_trans_12"][df["Flight_trans_12"]<LW]))
# Out:
# Number of outliers present in Flight_trans_12 Column :  565
# Number of outliers present in Flight_trans_12 Column :  0

# %%
df["Flight_trans_12"][df["Flight_trans_12"]>UW] = UW

# %%
print("Number of outliers present in Flight_trans_12 Column : ",len(df["Flight_trans_12"][df["Flight_trans_12"]>UW]))
print("Number of outliers present in Flight_trans_12 Column : ",len(df["Flight_trans_12"][df["Flight_trans_12"]<LW]))
# Out:
# Number of outliers present in Flight_trans_12 Column :  0
# Number of outliers present in Flight_trans_12 Column :  0

# %%
df["Flight_trans_12"].plot(kind='box')
# Out:
# <Axes: >

# %%
df["Award?"].plot(kind='box')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1  28143.0           0          1          1          1        174.0
# 1    2  19244.0           0          1          1          1        215.0
# 2    3  41354.0           0          1          1          1       4123.0
# 3    4  14776.0           0          1          1          1        500.0
# 4    5  97752.0           0          4          1          1      43300.0
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                0.0              0.0               7000       0
# 1            2                0.0              0.0               6968       0
# 2            4                0.0              0.0               7034       0
# 3            1                0.0              0.0               6952       0
# 4           26              777.5              2.5               6935       1

# %%
#Histogram
import seaborn as sns
import matplotlib.pyplot as plt
num_cols = df.select_dtypes(include=[np.number]).columns
for col in num_cols[1:]:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col],  bins=30)
    plt.title(f"Histogram of {col}")
    plt.show()

# %%
X = df.iloc[:,1:12]

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
SS_X = SS.fit_transform(X)
SS_X = pd.DataFrame(SS_X)
SS_X.columns = list(X)
SS_X
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.607258         0.0  -0.769578        0.0        0.0    -0.843091
# 1    -0.758947         0.0  -0.769578        0.0        0.0    -0.840822
# 2    -0.382070         0.0  -0.769578        0.0        0.0    -0.624581
# 3    -0.835106         0.0  -0.769578        0.0        0.0    -0.825052
# 4     0.579265         0.0   1.409471        0.0        0.0     1.543191
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.772038         0.0  -0.769578        0.0        0.0    -0.381007
# 3995  0.010506         0.0  -0.769578        0.0        0.0    -0.798437
# 3996  0.167530         0.0   0.683121        0.0        0.0     0.555335
# 3997 -0.151188         0.0  -0.769578        0.0        0.0    -0.825052
# 3998 -1.035562         0.0  -0.769578        0.0        0.0    -0.852718
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### Implementing Clustering Algorithms , Visualization and Evaluation and Performance Metrics:

# %% [markdown]
# ### K-Means Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# %%
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    labels = kmeans.fit_predict(SS_X)
    score = silhouette_score(SS_X, labels)
    print(f"k={i}, Silhouette Score={score:.4f}")
# Out:
# k=2, Silhouette Score=0.3182
# k=3, Silhouette Score=0.3293
# k=4, Silhouette Score=0.3071
# k=5, Silhouette Score=0.2802
# k=6, Silhouette Score=0.2723
# k=7, Silhouette Score=0.2198
# k=8, Silhouette Score=0.2437
# k=9, Silhouette Score=0.2452
# k=10, Silhouette Score=0.2494

# %%
from sklearn.cluster import KMeans
K_cluster = KMeans(n_clusters=3)
df["K_3"] = K_cluster.fit_predict(SS_X)

# %%
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,5], c=df["K_3"], cmap='rainbow')  
plt.show()

# %%
score=silhouette_score(SS_X,df["K_3"])
print("score:", np.round(score,3))
# Out:
# score: 0.329

# %% [markdown]
# ### Aglomerative Clustering

# %%
from sklearn.cluster import AgglomerativeClustering
linkage_methods = ["ward", "complete", "average", "single"]
for linkage in linkage_methods:
    for n in range(2, 11):
        agg = AgglomerativeClustering(n_clusters=n, linkage=linkage)
        labels = agg.fit_predict(SS_X)
        score = silhouette_score(SS_X, labels)
        print(f"Linkage={linkage}, Clusters={n}, Silhouette Score={score:.4f}")
# Out:
# Linkage=ward, Clusters=2, Silhouette Score=0.2717
# Linkage=ward, Clusters=3, Silhouette Score=0.2555
# Linkage=ward, Clusters=4, Silhouette Score=0.2026
# Linkage=ward, Clusters=5, Silhouette Score=0.2330
# Linkage=ward, Clusters=6, Silhouette Score=0.2338
# Linkage=ward, Clusters=7, Silhouette Score=0.1863
# Linkage=ward, Clusters=8, Silhouette Score=0.1944
# Linkage=ward, Clusters=9, Silhouette Score=0.2041
# Linkage=ward, Clusters=10, Silhouette Score=0.2098
# Linkage=complete, Clusters=2, Silhouette Score=0.3324
# Linkage=complete, Clusters=3, Silhouette Score=0.2942
# Linkage=complete, Clusters=4, Silhouette Score=0.1143
# Linkage=complete, Clusters=5, Silhouette Score=0.1055
# Linkage=complete, Clusters=6, Silhouette Score=0.1237
# Linkage=complete, Clusters=7, Silhouette Score=0.1244
# Linkage=complete, Clusters=8, Silhouette Score=0.1145
# Linkage=complete, Clusters=9, Silhouette Score=0.1052
# Linkage=complete, Clusters=10, Silhouette Score=0.1363
# ...

# %% [markdown]
# ### Single Linkage Method

# %%
from sklearn.cluster import AgglomerativeClustering
agg_cluster = AgglomerativeClustering(n_clusters=2,linkage='single')
df["single"] = agg_cluster.fit_predict(SS_X)

# %%
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,5], c=df["single"], cmap='rainbow')  
plt.show()

# %%
score=silhouette_score(SS_X,df["single"])
print("single linkage score:", np.round(score,3))
# Out:
# single linkage score: 0.221

# %% [markdown]
# ### Average Linkage Method

# %%
from sklearn.cluster import AgglomerativeClustering
agg_cluster = AgglomerativeClustering(n_clusters=3,linkage='average')
df["average"] = agg_cluster.fit_predict(SS_X)

# %%
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,5], c=df["average"], cmap='rainbow')  
plt.show()

# %%
score=silhouette_score(SS_X,df["average"])
print("average linkage score:", np.round(score,3))
# Out:
# average linkage score: 0.309

# %% [markdown]
# ### Ward Linkage Method

# %%
from sklearn.cluster import AgglomerativeClustering
agg_cluster = AgglomerativeClustering(n_clusters=2,linkage='ward')
df["ward"] = agg_cluster.fit_predict(SS_X)

# %%
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,5], c=df["ward"], cmap='rainbow')  
plt.show()

# %%
score=silhouette_score(SS_X,df["ward"])
print("ward linkage score:", np.round(score,3))
# Out:
# ward linkage score: 0.272

# %% [markdown]
# ### Complete Linkage Method

# %%
from sklearn.cluster import AgglomerativeClustering
agg_cluster = AgglomerativeClustering(n_clusters=2,linkage='complete')
df["complete"] = agg_cluster.fit_predict(SS_X)

# %%
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,5], c=df["complete"], cmap='rainbow')  
plt.show()

# %%
score=silhouette_score(SS_X,df["complete"])
print("complete linkage score:", np.round(score,3))
# Out:
# complete linkage score: 0.332

# %% [markdown]
# ### DBSCAN Clustering

# %%
from sklearn.cluster import dbscan
db_cluster = dbscan(SS_X,eps=0.5,min_samples=4)
df["db_cluster4"] = db_cluster[1]

# %%
df["db_cluster4"].value_counts()
# Out:
# db_cluster4
# -1     1525
#  0     1279
#  7      200
#  3      187
#  8      120
#        ...
#  27       4
#  25       4
#  54       3
#  34       3
#  35       3
# Name: count, Length: 66, dtype: int64

# %%
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,6], c=df["db_cluster4"], cmap='rainbow')  
plt.show()

# %%
score=silhouette_score(SS_X,df["db_cluster4"])
print("db_cluster score:", np.round(score,3))
# Out:
# db_cluster score: -0.191

# %%
db_cluster = dbscan(SS_X,eps=0.5,min_samples=3)
df["db_cluster3"] = db_cluster[1]

# %%
df["db_cluster3"].value_counts()
# Out:
# db_cluster3
# -1     1355
#  0     1282
#  8      203
#  4      194
#  9      127
#        ...
#  82       3
#  33       3
#  90       3
#  12       3
#  93       3
# Name: count, Length: 97, dtype: int64

# %%
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,6], c=df["db_cluster4"], cmap='rainbow')  
plt.show()

# %%
score=silhouette_score(SS_X,df["db_cluster3"])
print("db_cluster score:", np.round(score,3))
# Out:
# db_cluster score: -0.203

# %%
db_cluster = dbscan(X,eps=0.5,min_samples=2)
df["db_cluster2"] = db_cluster[1]
df["db_cluster2"].value_counts()
# Out:
# db_cluster2
# -1    3997
#  0       2
# Name: count, dtype: int64

# %%
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,6], c=df["db_cluster4"], cmap='rainbow')  
plt.show()

# %%
score=silhouette_score(X,df["db_cluster2"])
print("db_cluster score:", np.round(score,3))
# Out:
# db_cluster score: -0.176

# %%
db_cluster = dbscan(SS_X,eps=0.5,min_samples=6)
df["db_cluster5"] = db_cluster[1]
df["db_cluster5"].value_counts()
# Out:
# db_cluster5
# -1     1870
#  0     1257
#  4      191
#  1      178
#  6      111
#  9       96
#  14      42
#  21      41
#  2       39
#  17      21
#  11      21
#  12      19
#  7       19
#  18      16
#  10      14
#  8       11
#  3        8
#  5        7
#  20       7
#  22       7
#  13       6
#  15       6
#  16       6
#  19       6
# Name: count, dtype: int64

# %%
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,6], c=df["db_cluster5"], cmap='rainbow')  
plt.show()

# %%
score=silhouette_score(SS_X,df["db_cluster5"])
print("db_cluster score:", np.round(score,3))
# Out:
# db_cluster score: -0.169

# %%
db_cluster6 = dbscan(SS_X,eps=0.5,min_samples=6)
df["db_cluster6"] = db_cluster[1]
df["db_cluster6"].value_counts()
# Out:
# db_cluster6
# -1     1870
#  0     1257
#  4      191
#  1      178
#  6      111
#  9       96
#  14      42
#  21      41
#  2       39
#  17      21
#  11      21
#  12      19
#  7       19
#  18      16
#  10      14
#  8       11
#  3        8
#  5        7
#  20       7
#  22       7
#  13       6
#  15       6
#  16       6
#  19       6
# Name: count, dtype: int64

# %%
plt.scatter(SS_X.iloc[:,0], SS_X.iloc[:,6], c=df["db_cluster6"], cmap='rainbow')  
plt.show()

# %%
score=silhouette_score(X,df["db_cluster6"])
print("db_cluster score:", np.round(score,3))
# Out:
# db_cluster score: -0.592

# %% [markdown]
# ### Cluster Analysis and Interpretation:

# %%
#best-performing models (Agglomerative)
from sklearn.cluster import KMeans
K_cluster = KMeans(n_clusters=3)
K_cluster.fit(SS_X)
df['K_3'] = K_cluster.labels_

# %%
plt.scatter(SS_X['Balance'], SS_X['Bonus_miles'], c=df['K_3'], cmap='rainbow')
plt.xlabel('Balance')
plt.ylabel('Bonus Miles')
plt.show()

# %%
plt.scatter(SS_X['Bonus_trans'], SS_X['cc1_miles'], c=df['K_3'], cmap='rainbow')
plt.xlabel('Bonus_trans')
plt.ylabel('cc1_miles')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
agg_cluster = AgglomerativeClustering(n_clusters=2,linkage='complete')
df["ward"] = agg_cluster.fit_predict(SS_X)

# %%
plt.scatter(SS_X['cc3_miles'], SS_X['Flight_miles_12mo'], c=df['ward'], cmap='rainbow')
plt.xlabel('cc3_miles')
plt.ylabel('Flight_miles_12mo')
plt.show()

# %%
plt.scatter(SS_X['Days_since_enroll'], SS_X['Bonus_trans'], c=df['ward'], cmap='rainbow')
plt.xlabel('Days_since_enroll')
plt.ylabel('Bonus_trans')
plt.show()
